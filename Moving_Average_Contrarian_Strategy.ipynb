# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulombale/swing_strategy_rahul/blob/main/Moving_Average_Contrarian_Strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.graph_objects as go
from google.colab import drive
from datetime import datetime
import os

# --- 1. SETUP AND CONFIGURATION ---

# Mount Google Drive
try:
    drive.mount('/content/drive', force_remount=True)
except Exception as e:
    print(f"Could not mount drive: {e}")

# --- INPUT VARIABLES ---
DATA_FOLDER_DATE = '2025-06-17'
DATA_BASE_PATH = '/content/drive/My Drive/stock_data/'
BASE_DATA_PATH = f'{DATA_BASE_PATH}{DATA_FOLDER_DATE}/'
SOURCE_FILE_V40 = 'v40_token.csv' # This strategy is only for V40 stocks

# --- OUTPUT FILE NAMES ---
COMPLETED_TRADES_FILE = 'ma_strategy_completed.csv'
OPEN_TRADES_FILE = 'ma_strategy_open.csv'

# Strategy Parameters
CAPITAL_PER_TRADE = 100000  # Note: The prompt mentioned "3% in one trade". This is interpreted as a fixed capital amount for simplicity.
AVERAGE_DOWN_PERCENT = -0.10 # -10% drop to trigger averaging
TICKER_COLUMN_NAME = 'ticker'


# --- 2. CORE FUNCTIONS ---

def load_ma_data(file_path, stock_name_for_print):
    """Loads and preprocesses stock data, calculating multiple SMAs."""
    if not os.path.exists(file_path):
        print(f"      - WARNING: Data file not found for {stock_name_for_print} at {file_path}. Skipping.")
        return None
    try:
        df = pd.read_csv(file_path)
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df.set_index('timestamp', inplace=True)
        df.sort_index(inplace=True)
        # Calculate all required SMAs
        df['sma_20'] = df['close'].rolling(window=20).mean()
        df['sma_50'] = df['close'].rolling(window=50).mean()
        df['sma_200'] = df['close'].rolling(window=200).mean()
        # Drop rows with NaN values that result from SMA calculation
        df.dropna(inplace=True)
        return df
    except Exception as e:
        print(f"      - ERROR: Could not process file for {stock_name_for_print}. Reason: {e}")
        return None

def execute_ma_backtest(df, stock_name, capital):
    """
    Executes the Moving Average Contrarian Strategy backtest for a single stock.
    """
    completed_trades = []
    open_trades = []

    in_position = False
    position_details = {} # To store info like entry_price, shares, average_count etc.

    # We start from the second row to use the previous day's close for decisions
    for i in range(1, len(df)):
        prev_row = df.iloc[i-1]
        curr_row = df.iloc[i]

        # --- A. CHECK FOR TRADE ACTION ---
        if not in_position:
            # --- CHECK FOR BUY SIGNAL ---
            buy_condition = (prev_row['close'] < prev_row['sma_20'] and
                             prev_row['sma_20'] < prev_row['sma_50'] and
                             prev_row['sma_50'] < prev_row['sma_200'])

            if buy_condition:
                entry_price = curr_row['open']
                num_shares = int(capital / entry_price)
                if num_shares == 0: continue

                in_position = True
                position_details = {
                    'entry_date': curr_row.name,
                    'initial_entry_price': entry_price,
                    'avg_price': entry_price,
                    'total_shares': num_shares,
                    'total_investment': num_shares * entry_price,
                    'average_count': 0,
                    'buy_points': [(curr_row.name, entry_price)] # List to store buy dates and prices
                }
                print(f"  - [{stock_name} @ {curr_row.name.date()}] BUY SIGNAL TRIGGERED. Buying {num_shares} shares at {entry_price:.2f}")

        else: # If we are already in a position
            # --- 1. CHECK FOR AVERAGING DOWN ---
            price_change_from_initial = (curr_row['open'] - position_details['initial_entry_price']) / position_details['initial_entry_price']

            if position_details['average_count'] < 1 and price_change_from_initial <= AVERAGE_DOWN_PERCENT:
                avg_price = curr_row['open']
                num_shares = int(capital / avg_price)
                if num_shares == 0: continue

                # Update position details after averaging
                new_investment = num_shares * avg_price
                position_details['total_investment'] += new_investment
                position_details['total_shares'] += num_shares
                position_details['avg_price'] = position_details['total_investment'] / position_details['total_shares']
                position_details['average_count'] += 1
                position_details['buy_points'].append((curr_row.name, avg_price))
                print(f"  - [{stock_name} @ {curr_row.name.date()}] AVERAGING DOWN. Buying {num_shares} more shares at {avg_price:.2f}")

            # --- 2. CHECK FOR SELL SIGNAL ---
            sell_condition = (prev_row['close'] > prev_row['sma_20'] and
                              prev_row['sma_20'] > prev_row['sma_50'] and
                              prev_row['sma_50'] > prev_row['sma_200'])

            if sell_condition:
                exit_price = curr_row['open']
                sale_value = position_details['total_shares'] * exit_price
                profit = sale_value - position_details['total_investment']

                completed_trades.append({
                    'Stock': stock_name,
                    'Entry Date': position_details['entry_date'],
                    'Exit Date': curr_row.name,
                    'Avg Entry Price': position_details['avg_price'],
                    'Exit Price': exit_price,
                    'Investment': position_details['total_investment'],
                    'Sale Value': sale_value,
                    'Profit': profit,
                    'Profit %': (profit / position_details['total_investment']) * 100,
                    'Times Averaged': position_details['average_count'],
                    'Buy Points': position_details['buy_points']
                })
                print(f"  - [{stock_name} @ {curr_row.name.date()}] SELL SIGNAL TRIGGERED. Selling {position_details['total_shares']} shares at {exit_price:.2f}")

                # Reset state
                in_position = False
                position_details = {}

    # --- B. HANDLE OPEN TRADES AT THE END OF DATA ---
    if in_position:
        last_close = df.iloc[-1]['close']
        unrealized_pnl = (last_close * position_details['total_shares']) - position_details['total_investment']

        open_trades.append({
            'Stock': stock_name,
            'Status': 'Open',
            'Entry Date': position_details['entry_date'],
            'Avg Entry Price': position_details['avg_price'],
            'Investment': position_details['total_investment'],
            'Last Known Date': df.index[-1],
            'Last Price': last_close,
            'Unrealized P/L': unrealized_pnl,
            'Unrealized P/L %': (unrealized_pnl / position_details['total_investment']) * 100,
            'Shares': position_details['total_shares']
        })

    return completed_trades, open_trades


def plot_ma_trade(df, trade):
    """Generates an interactive chart for a completed MA strategy trade."""
    plot_start = trade['Entry Date'] - pd.Timedelta(days=30)
    plot_end = trade['Exit Date'] + pd.Timedelta(days=30)
    chart_df = df.loc[plot_start:plot_end]

    fig = go.Figure()

    # Candlestick chart
    fig.add_trace(go.Candlestick(x=chart_df.index, open=chart_df['open'], high=chart_df['high'],
                                  low=chart_df['low'], close=chart_df['close'], name=trade['Stock']))
    # SMA Lines
    fig.add_trace(go.Scatter(x=chart_df.index, y=chart_df['sma_20'], mode='lines', name='20 SMA', line=dict(color='green', width=1)))
    fig.add_trace(go.Scatter(x=chart_df.index, y=chart_df['sma_50'], mode='lines', name='50 SMA', line=dict(color='red', width=1)))
    fig.add_trace(go.Scatter(x=chart_df.index, y=chart_df['sma_200'], mode='lines', name='200 SMA', line=dict(color='black', width=1.5)))

    # Mark Buy and Sell points
    buy_dates = [p[0] for p in trade['Buy Points']]
    buy_prices = [p[1] for p in trade['Buy Points']]
    fig.add_trace(go.Scatter(x=buy_dates, y=buy_prices, mode='markers', name='Buy Points',
                              marker=dict(color='blue', size=12, symbol='triangle-up', line=dict(width=2, color='white'))))
    fig.add_trace(go.Scatter(x=[trade['Exit Date']], y=[trade['Exit Price']], mode='markers', name='Sell Point',
                              marker=dict(color='fuchsia', size=12, symbol='triangle-down', line=dict(width=2, color='white'))))

    fig.update_layout(
        title=f"Moving Average Trade: {trade['Stock']} ({trade['Entry Date'].date()} to {trade['Exit Date'].date()})",
        xaxis_title="Date", yaxis_title="Price (INR)", xaxis_rangeslider_visible=False,
        template="plotly_white", legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01))
    fig.show()


# --- 3. MAIN EXECUTION BLOCK with Toggle ---
if __name__ == '__main__':
    # --- TOGGLE AND SETTINGS ---
    RUN_SINGLE_STOCK = False
    TICKER_TO_TEST = 'ASIANPAINT-EQ'
    # ---------------------------

    all_completed_trades = []
    all_open_trades = []

    if RUN_SINGLE_STOCK:
        print(f"--- Running single stock analysis for: {TICKER_TO_TEST} ---")
        data_file_path = f"{BASE_DATA_PATH}{TICKER_TO_TEST}.csv"
        df = load_ma_data(data_file_path, TICKER_TO_TEST)
        if df is not None:
            completed, opened = execute_ma_backtest(df, TICKER_TO_TEST, CAPITAL_PER_TRADE)
            if completed:
                all_completed_trades.extend(completed)
                for trade in completed:
                    plot_ma_trade(df, trade)
            if opened:
                all_open_trades.extend(opened)
    else:
        print("--- Starting Moving Average Strategy Batch Backtest (V40 Stocks Only) ---")
        stock_list_path = os.path.join(DATA_BASE_PATH, SOURCE_FILE_V40)
        try:
            stocks_df = pd.read_csv(stock_list_path)
            tickers = stocks_df[TICKER_COLUMN_NAME].dropna().unique()
            print(f"  - Found {len(tickers)} unique stocks in {SOURCE_FILE_V40}.")
            for ticker in tickers:
                print(f"\n[2] Analyzing stock: {ticker}")
                data_file_path = f"{BASE_DATA_PATH}{ticker}.csv"
                df = load_ma_data(data_file_path, ticker)
                if df is not None:
                    completed, opened = execute_ma_backtest(df, ticker, CAPITAL_PER_TRADE)
                    if completed:
                        all_completed_trades.extend(completed)
                    if opened:
                        all_open_trades.extend(opened)
        except FileNotFoundError:
            print(f"  - ERROR: Stock list file not found at {stock_list_path}.")

    # --- 4. FINAL SUMMARY AND OUTPUT ---
    print("\n" + "="*82)
    print("--- BACKTESTING COMPLETE: FINAL SUMMARY ---")
    print("="*82)

    if all_completed_trades:
        completed_df = pd.DataFrame(all_completed_trades).drop(columns=['Buy Points']) # Drop list column for clean CSV
        print("\n" + "="*28 + " COMPLETED TRADES SUMMARY " + "="*28)
        print(completed_df.to_string())
        output_path = os.path.join(DATA_BASE_PATH, COMPLETED_TRADES_FILE)
        completed_df.to_csv(output_path, index=False)
        print(f"\nSaved completed trades summary to '{output_path}'")
    else:
        print("\nNo completed trades were found.")

    if all_open_trades:
        open_df = pd.DataFrame(all_open_trades)
        print("\n" + "="*24 + " OPEN TRADES (TARGET NOT MET) SUMMARY " + "="*23)
        print(open_df.to_string())
        output_path = os.path.join(DATA_BASE_PATH, OPEN_TRADES_FILE)
        open_df.to_csv(output_path, index=False)
        print(f"\nSaved open trades summary to '{output_path}'")
    else:
        print("\nNo open trades were found at the end of the backtest period.")
# Out:
# Mounted at /content/drive
# --- Starting Moving Average Strategy Batch Backtest (V40 Stocks Only) ---
#   - Found 40 unique stocks in v40_token.csv.
#
# [2] Analyzing stock: LT-EQ
#   - [LT-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 112 shares at 890.30
#   - [LT-EQ @ 2020-11-27] SELL SIGNAL TRIGGERED. Selling 112 shares at 1129.00
#   - [LT-EQ @ 2022-04-27] BUY SIGNAL TRIGGERED. Buying 59 shares at 1675.00
#   - [LT-EQ @ 2022-06-20] AVERAGING DOWN. Buying 67 more shares at 1490.00
#   - [LT-EQ @ 2022-09-08] SELL SIGNAL TRIGGERED. Selling 126 shares at 1967.90
#   - [LT-EQ @ 2025-02-13] BUY SIGNAL TRIGGERED. Buying 30 shares at 3289.65
#
# [2] Analyzing stock: RELIANCE-EQ
#   - [RELIANCE-EQ @ 2021-04-13] BUY SIGNAL TRIGGERED. Buying 114 shares at 873.36
#   - [RELIANCE-EQ @ 2021-08-27] SELL SIGNAL TRIGGERED. Selling 114 shares at 1015.44
#   - [RELIANCE-EQ @ 2023-02-03] BUY SIGNAL TRIGGERED. Buying 93 shares at 1066.28
#   - [RELIANCE-EQ @ 2023-06-30] SELL SIGNAL TRIGGERED. Selling 93 shares at 1155.89
#   - [RELIANCE-EQ @ 2024-10-22] BUY SIGNAL TRIGGERED. Buying 73 shares at 1369.20
#   - [RELIANCE-EQ @ 2024-11-22] AVERAGING DOWN. Buying 81 more shares at 1229.40
#   - [RELIANCE-EQ @ 2025-06-05] SELL SIGNAL TRIGGERED. Selling 154 shares at 1428.00
#
# [2] Analyzing stock: HDFCBANK-EQ
#   - [HDFCBANK-EQ @ 2022-02-15] BUY SIGNAL TRIGGERED. Buying 67 shares at 1476.00
#   - [HDFCBANK-EQ @ 2022-03-07] AVERAGING DOWN. Buying 75 more shares at 1318.50
#   - [HDFCBANK-EQ @ 2022-09-15] SELL SIGNAL TRIGGERED. Selling 142 shares at 1530.00
#   - [HDFCBANK-EQ @ 2023-09-21] BUY SIGNAL TRIGGERED. Buying 64 shares at 1553.00
#   - [HDFCBANK-EQ @ 2024-01-24] AVERAGING DOWN. Buying 72 more shares at 1380.25
#   - [HDFCBANK-EQ @ 2024-06-26] SELL SIGNAL TRIGGERED. Selling 136 shares at 1707.95
#
# [2] Analyzing stock: ICICIBANK-EQ
#   - [ICICIBANK-EQ @ 2022-05-23] BUY SIGNAL TRIGGERED. Buying 140 shares at 709.55
#   - [ICICIBANK-EQ @ 2022-08-11] SELL SIGNAL TRIGGERED. Selling 140 shares at 860.05
#   - [ICICIBANK-EQ @ 2023-03-28] BUY SIGNAL TRIGGERED. Buying 116 shares at 855.55
#   - [ICICIBANK-EQ @ 2023-05-16] SELL SIGNAL TRIGGERED. Selling 116 shares at 950.00
#
# [2] Analyzing stock: AXISBANK-EQ
#   - [AXISBANK-EQ @ 2021-12-21] BUY SIGNAL TRIGGERED. Buying 146 shares at 683.00
#   - [AXISBANK-EQ @ 2022-04-18] SELL SIGNAL TRIGGERED. Selling 146 shares at 780.00
#   - [AXISBANK-EQ @ 2022-05-16] BUY SIGNAL TRIGGERED. Buying 156 shares at 639.85
#   - [AXISBANK-EQ @ 2022-09-09] SELL SIGNAL TRIGGERED. Selling 156 shares at 787.95
#   - [AXISBANK-EQ @ 2024-12-13] BUY SIGNAL TRIGGERED. Buying 87 shares at 1141.00
#   - [AXISBANK-EQ @ 2025-01-13] AVERAGING DOWN. Buying 97 more shares at 1026.60
#   - [AXISBANK-EQ @ 2025-05-22] SELL SIGNAL TRIGGERED. Selling 184 shares at 1196.70
#
# [2] Analyzing stock: KOTAKBANK-EQ
#   - [KOTAKBANK-EQ @ 2021-07-13] BUY SIGNAL TRIGGERED. Buying 57 shares at 1743.00
#   - [KOTAKBANK-EQ @ 2021-10-13] SELL SIGNAL TRIGGERED. Selling 57 shares at 2004.00
#   - [KOTAKBANK-EQ @ 2022-02-22] BUY SIGNAL TRIGGERED. Buying 55 shares at 1790.00
#   - [KOTAKBANK-EQ @ 2022-09-13] SELL SIGNAL TRIGGERED. Selling 55 shares at 1933.00
#   - [KOTAKBANK-EQ @ 2023-02-07] BUY SIGNAL TRIGGERED. Buying 57 shares at 1752.20
#   - [KOTAKBANK-EQ @ 2023-05-29] SELL SIGNAL TRIGGERED. Selling 57 shares at 1956.50
#   - [KOTAKBANK-EQ @ 2023-09-22] BUY SIGNAL TRIGGERED. Buying 56 shares at 1758.00
#   - [KOTAKBANK-EQ @ 2024-09-17] SELL SIGNAL TRIGGERED. Selling 56 shares at 1839.40
#
# [2] Analyzing stock: HCLTECH-EQ
#   - [HCLTECH-EQ @ 2022-04-20] BUY SIGNAL TRIGGERED. Buying 93 shares at 1075.00
#   - [HCLTECH-EQ @ 2022-06-17] AVERAGING DOWN. Buying 104 more shares at 952.40
#   - [HCLTECH-EQ @ 2022-12-07] SELL SIGNAL TRIGGERED. Selling 197 shares at 1114.00
#   - [HCLTECH-EQ @ 2025-03-19] BUY SIGNAL TRIGGERED. Buying 64 shares at 1558.50
#   - [HCLTECH-EQ @ 2025-04-07] AVERAGING DOWN. Buying 74 more shares at 1345.00
#
# [2] Analyzing stock: INFY-EQ
#   - [INFY-EQ @ 2022-05-12] BUY SIGNAL TRIGGERED. Buying 66 shares at 1514.00
#   - [INFY-EQ @ 2022-09-26] AVERAGING DOWN. Buying 73 more shares at 1360.00
#   - [INFY-EQ @ 2023-02-10] SELL SIGNAL TRIGGERED. Selling 139 shares at 1612.95
#   - [INFY-EQ @ 2023-04-03] BUY SIGNAL TRIGGERED. Buying 69 shares at 1435.00
#   - [INFY-EQ @ 2023-04-17] AVERAGING DOWN. Buying 79 more shares at 1250.30
#   - [INFY-EQ @ 2023-09-25] SELL SIGNAL TRIGGERED. Selling 148 shares at 1489.85
#   - [INFY-EQ @ 2024-05-31] BUY SIGNAL TRIGGERED. Buying 70 shares at 1409.80
#   - [INFY-EQ @ 2024-07-19] SELL SIGNAL TRIGGERED. Selling 70 shares at 1844.00
#   - [INFY-EQ @ 2025-03-20] BUY SIGNAL TRIGGERED. Buying 62 shares at 1592.00
#   - [INFY-EQ @ 2025-04-07] AVERAGING DOWN. Buying 73 more shares at 1352.00
#
# [2] Analyzing stock: TCS-EQ
#   - [TCS-EQ @ 2022-05-06] BUY SIGNAL TRIGGERED. Buying 28 shares at 3459.00
#   - [TCS-EQ @ 2022-06-17] AVERAGING DOWN. Buying 32 more shares at 3092.00
#   - [TCS-EQ @ 2023-01-27] SELL SIGNAL TRIGGERED. Selling 60 shares at 3426.00
#   - [TCS-EQ @ 2023-05-18] BUY SIGNAL TRIGGERED. Buying 30 shares at 3225.95
#   - [TCS-EQ @ 2023-07-18] SELL SIGNAL TRIGGERED. Selling 30 shares at 3476.00
#   - [TCS-EQ @ 2025-02-18] BUY SIGNAL TRIGGERED. Buying 25 shares at 3898.40
#   - [TCS-EQ @ 2025-03-03] AVERAGING DOWN. Buying 28 more shares at 3485.00
#
# [2] Analyzing stock: HDFCAMC-EQ
#   - [HDFCAMC-EQ @ 2020-10-27] BUY SIGNAL TRIGGERED. Buying 43 shares at 2290.00
#   - [HDFCAMC-EQ @ 2020-12-21] SELL SIGNAL TRIGGERED. Selling 43 shares at 2861.90
#   - [HDFCAMC-EQ @ 2021-11-17] BUY SIGNAL TRIGGERED. Buying 37 shares at 2652.05
#   - [HDFCAMC-EQ @ 2021-12-21] AVERAGING DOWN. Buying 42 more shares at 2335.00
#   - [HDFCAMC-EQ @ 2022-12-01] SELL SIGNAL TRIGGERED. Selling 79 shares at 2190.30
#   - [HDFCAMC-EQ @ 2023-03-06] BUY SIGNAL TRIGGERED. Buying 55 shares at 1800.00
#   - [HDFCAMC-EQ @ 2023-07-13] SELL SIGNAL TRIGGERED. Selling 55 shares at 2349.95
#   - [HDFCAMC-EQ @ 2025-02-04] BUY SIGNAL TRIGGERED. Buying 26 shares at 3844.95
#   - [HDFCAMC-EQ @ 2025-05-26] SELL SIGNAL TRIGGERED. Selling 26 shares at 4810.00
#
# [2] Analyzing stock: NAM-INDIA-EQ
#   - [NAM-INDIA-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 369 shares at 270.35
#   - [NAM-INDIA-EQ @ 2020-12-11] SELL SIGNAL TRIGGERED. Selling 369 shares at 308.95
#   - [NAM-INDIA-EQ @ 2022-01-25] BUY SIGNAL TRIGGERED. Buying 304 shares at 328.00
#   - [NAM-INDIA-EQ @ 2022-03-08] AVERAGING DOWN. Buying 343 more shares at 291.20
#   - [NAM-INDIA-EQ @ 2023-07-10] SELL SIGNAL TRIGGERED. Selling 647 shares at 286.50
#   - [NAM-INDIA-EQ @ 2025-02-20] BUY SIGNAL TRIGGERED. Buying 191 shares at 523.35
#   - [NAM-INDIA-EQ @ 2025-06-10] SELL SIGNAL TRIGGERED. Selling 191 shares at 809.00
#
# [2] Analyzing stock: HDFCLIFE-EQ
#   - [HDFCLIFE-EQ @ 2021-12-21] BUY SIGNAL TRIGGERED. Buying 156 shares at 640.00
#   - [HDFCLIFE-EQ @ 2022-02-15] AVERAGING DOWN. Buying 177 more shares at 564.00
#   - [HDFCLIFE-EQ @ 2023-01-04] SELL SIGNAL TRIGGERED. Selling 333 shares at 599.00
#   - [HDFCLIFE-EQ @ 2023-02-28] BUY SIGNAL TRIGGERED. Buying 203 shares at 490.90
#   - [HDFCLIFE-EQ @ 2023-06-12] SELL SIGNAL TRIGGERED. Selling 203 shares at 585.95
#   - [HDFCLIFE-EQ @ 2024-02-16] BUY SIGNAL TRIGGERED. Buying 169 shares at 588.50
#   - [HDFCLIFE-EQ @ 2024-08-08] SELL SIGNAL TRIGGERED. Selling 169 shares at 691.10
#   - [HDFCLIFE-EQ @ 2025-01-15] BUY SIGNAL TRIGGERED. Buying 165 shares at 604.50
#   - [HDFCLIFE-EQ @ 2025-05-14] SELL SIGNAL TRIGGERED. Selling 165 shares at 740.00
#
# [2] Analyzing stock: ICICIPRULI-EQ
#   - [ICICIPRULI-EQ @ 2022-01-20] BUY SIGNAL TRIGGERED. Buying 174 shares at 573.80
#   - [ICICIPRULI-EQ @ 2022-02-09] AVERAGING DOWN. Buying 194 more shares at 515.00
#   - [ICICIPRULI-EQ @ 2022-09-02] SELL SIGNAL TRIGGERED. Selling 368 shares at 593.50
#   - [ICICIPRULI-EQ @ 2022-11-23] BUY SIGNAL TRIGGERED. Buying 213 shares at 468.20
#   - [ICICIPRULI-EQ @ 2023-02-02] AVERAGING DOWN. Buying 253 more shares at 394.00
#   - [ICICIPRULI-EQ @ 2023-06-28] SELL SIGNAL TRIGGERED. Selling 466 shares at 582.40
#   - [ICICIPRULI-EQ @ 2024-02-05] BUY SIGNAL TRIGGERED. Buying 197 shares at 507.00
#   - [ICICIPRULI-EQ @ 2024-04-10] SELL SIGNAL TRIGGERED. Selling 197 shares at 627.90
#   - [ICICIPRULI-EQ @ 2025-01-22] BUY SIGNAL TRIGGERED. Buying 161 shares at 620.00
#   - [ICICIPRULI-EQ @ 2025-03-03] AVERAGING DOWN. Buying 181 more shares at 552.10
#
# [2] Analyzing stock: ICICIGI-EQ
#   - [ICICIGI-EQ @ 2021-12-16] BUY SIGNAL TRIGGERED. Buying 71 shares at 1407.00
#   - [ICICIGI-EQ @ 2022-02-22] AVERAGING DOWN. Buying 80 more shares at 1247.00
#   - [ICICIGI-EQ @ 2023-06-30] SELL SIGNAL TRIGGERED. Selling 151 shares at 1332.00
#   - [ICICIGI-EQ @ 2025-01-14] BUY SIGNAL TRIGGERED. Buying 54 shares at 1835.70
#   - [ICICIGI-EQ @ 2025-03-05] AVERAGING DOWN. Buying 60 more shares at 1639.70
#
# [2] Analyzing stock: BAJAJFINSV-EQ
#   - [BAJAJFINSV-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 168 shares at 595.00
#   - [BAJAJFINSV-EQ @ 2020-11-24] SELL SIGNAL TRIGGERED. Selling 168 shares at 881.99
#   - [BAJAJFINSV-EQ @ 2022-05-04] BUY SIGNAL TRIGGERED. Buying 66 shares at 1495.74
#   - [BAJAJFINSV-EQ @ 2022-05-12] AVERAGING DOWN. Buying 75 more shares at 1326.90
#   - [BAJAJFINSV-EQ @ 2022-09-20] SELL SIGNAL TRIGGERED. Selling 141 shares at 1785.00
#   - [BAJAJFINSV-EQ @ 2023-02-23] BUY SIGNAL TRIGGERED. Buying 73 shares at 1362.00
#   - [BAJAJFINSV-EQ @ 2023-07-17] SELL SIGNAL TRIGGERED. Selling 73 shares at 1620.00
#   - [BAJAJFINSV-EQ @ 2024-08-20] BUY SIGNAL TRIGGERED. Buying 64 shares at 1554.95
#   - [BAJAJFINSV-EQ @ 2024-09-05] SELL SIGNAL TRIGGERED. Selling 64 shares at 1868.00
#   - [BAJAJFINSV-EQ @ 2025-01-01] BUY SIGNAL TRIGGERED. Buying 63 shares at 1565.00
#   - [BAJAJFINSV-EQ @ 2025-02-10] SELL SIGNAL TRIGGERED. Selling 63 shares at 1804.90
#
# [2] Analyzing stock: BAJAJHLDNG-EQ
#   - [BAJAJHLDNG-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 41 shares at 2431.05
#   - [BAJAJHLDNG-EQ @ 2020-12-02] SELL SIGNAL TRIGGERED. Selling 41 shares at 3094.30
#   - [BAJAJHLDNG-EQ @ 2022-06-24] BUY SIGNAL TRIGGERED. Buying 22 shares at 4525.00
#   - [BAJAJHLDNG-EQ @ 2022-09-12] SELL SIGNAL TRIGGERED. Selling 22 shares at 6660.65
#
# [2] Analyzing stock: BAJFINANCE-EQ
#   - [BAJFINANCE-EQ @ 2022-05-11] BUY SIGNAL TRIGGERED. Buying 16 shares at 5957.00
#   - [BAJFINANCE-EQ @ 2022-06-14] AVERAGING DOWN. Buying 18 more shares at 5347.00
#   - [BAJFINANCE-EQ @ 2022-09-14] SELL SIGNAL TRIGGERED. Selling 34 shares at 7272.15
#   - [BAJFINANCE-EQ @ 2023-01-12] BUY SIGNAL TRIGGERED. Buying 16 shares at 5906.55
#   - [BAJFINANCE-EQ @ 2023-06-21] SELL SIGNAL TRIGGERED. Selling 16 shares at 7275.00
#   - [BAJFINANCE-EQ @ 2024-02-13] BUY SIGNAL TRIGGERED. Buying 15 shares at 6600.00
#   - [BAJFINANCE-EQ @ 2024-09-26] SELL SIGNAL TRIGGERED. Selling 15 shares at 7640.00
#   - [BAJFINANCE-EQ @ 2024-12-23] BUY SIGNAL TRIGGERED. Buying 14 shares at 6897.00
#   - [BAJFINANCE-EQ @ 2025-01-29] SELL SIGNAL TRIGGERED. Selling 14 shares at 7657.25
#
# [2] Analyzing stock: HINDUNILVR-EQ
#   - [HINDUNILVR-EQ @ 2021-12-17] BUY SIGNAL TRIGGERED. Buying 43 shares at 2303.00
#   - [HINDUNILVR-EQ @ 2022-03-07] AVERAGING DOWN. Buying 50 more shares at 1979.50
#   - [HINDUNILVR-EQ @ 2022-07-19] SELL SIGNAL TRIGGERED. Selling 93 shares at 2549.95
#   - [HINDUNILVR-EQ @ 2023-09-13] BUY SIGNAL TRIGGERED. Buying 40 shares at 2494.00
#   - [HINDUNILVR-EQ @ 2024-03-21] AVERAGING DOWN. Buying 44 more shares at 2234.00
#   - [HINDUNILVR-EQ @ 2024-07-16] SELL SIGNAL TRIGGERED. Selling 84 shares at 2625.95
#   - [HINDUNILVR-EQ @ 2024-12-19] BUY SIGNAL TRIGGERED. Buying 42 shares at 2347.00
#
# [2] Analyzing stock: NESTLEIND-EQ
#   - [NESTLEIND-EQ @ 2020-10-14] BUY SIGNAL TRIGGERED. Buying 63 shares at 1567.40
#   - [NESTLEIND-EQ @ 2020-12-02] SELL SIGNAL TRIGGERED. Selling 63 shares at 1741.82
#   - [NESTLEIND-EQ @ 2021-05-14] BUY SIGNAL TRIGGERED. Buying 59 shares at 1671.70
#   - [NESTLEIND-EQ @ 2021-05-31] SELL SIGNAL TRIGGERED. Selling 59 shares at 1750.90
#   - [NESTLEIND-EQ @ 2022-03-07] BUY SIGNAL TRIGGERED. Buying 58 shares at 1710.00
#   - [NESTLEIND-EQ @ 2022-08-22] SELL SIGNAL TRIGGERED. Selling 58 shares at 1940.10
#   - [NESTLEIND-EQ @ 2024-10-31] BUY SIGNAL TRIGGERED. Buying 43 shares at 2287.00
#   - [NESTLEIND-EQ @ 2025-06-02] SELL SIGNAL TRIGGERED. Selling 43 shares at 2400.00
#
# [2] Analyzing stock: PGHH-EQ
#   - [PGHH-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 10 shares at 9932.00
#   - [PGHH-EQ @ 2020-12-04] SELL SIGNAL TRIGGERED. Selling 10 shares at 10997.00
#   - [PGHH-EQ @ 2022-05-18] BUY SIGNAL TRIGGERED. Buying 7 shares at 13284.00
#   - [PGHH-EQ @ 2023-01-03] SELL SIGNAL TRIGGERED. Selling 7 shares at 14278.00
#   - [PGHH-EQ @ 2023-02-14] BUY SIGNAL TRIGGERED. Buying 7 shares at 13746.50
#   - [PGHH-EQ @ 2023-07-12] SELL SIGNAL TRIGGERED. Selling 7 shares at 14712.45
#   - [PGHH-EQ @ 2024-04-03] BUY SIGNAL TRIGGERED. Buying 6 shares at 16199.00
#   - [PGHH-EQ @ 2024-08-13] SELL SIGNAL TRIGGERED. Selling 6 shares at 17200.00
#   - [PGHH-EQ @ 2024-11-06] BUY SIGNAL TRIGGERED. Buying 6 shares at 16050.00
#   - [PGHH-EQ @ 2025-01-27] AVERAGING DOWN. Buying 6 more shares at 14410.00
#
# [2] Analyzing stock: PIDILITIND-EQ
#   - [PIDILITIND-EQ @ 2022-05-10] BUY SIGNAL TRIGGERED. Buying 45 shares at 2217.05
#   - [PIDILITIND-EQ @ 2022-08-30] SELL SIGNAL TRIGGERED. Selling 45 shares at 2715.50
#   - [PIDILITIND-EQ @ 2023-02-16] BUY SIGNAL TRIGGERED. Buying 43 shares at 2319.00
#   - [PIDILITIND-EQ @ 2023-06-26] SELL SIGNAL TRIGGERED. Selling 43 shares at 2650.00
#   - [PIDILITIND-EQ @ 2023-10-26] BUY SIGNAL TRIGGERED. Buying 43 shares at 2321.00
#   - [PIDILITIND-EQ @ 2024-01-03] SELL SIGNAL TRIGGERED. Selling 43 shares at 2749.00
#   - [PIDILITIND-EQ @ 2025-01-01] BUY SIGNAL TRIGGERED. Buying 34 shares at 2904.25
#
# [2] Analyzing stock: COLPAL-EQ
#   - [COLPAL-EQ @ 2021-11-22] BUY SIGNAL TRIGGERED. Buying 67 shares at 1476.90
#   - [COLPAL-EQ @ 2022-05-19] SELL SIGNAL TRIGGERED. Selling 67 shares at 1589.00
#   - [COLPAL-EQ @ 2023-01-13] BUY SIGNAL TRIGGERED. Buying 66 shares at 1493.85
#   - [COLPAL-EQ @ 2023-06-02] SELL SIGNAL TRIGGERED. Selling 66 shares at 1612.00
#   - [COLPAL-EQ @ 2024-12-19] BUY SIGNAL TRIGGERED. Buying 36 shares at 2756.75
#   - [COLPAL-EQ @ 2025-02-17] AVERAGING DOWN. Buying 40 more shares at 2471.00
#
# [2] Analyzing stock: DABUR-EQ
#   - [DABUR-EQ @ 2022-01-19] BUY SIGNAL TRIGGERED. Buying 177 shares at 563.90
#   - [DABUR-EQ @ 2022-03-08] AVERAGING DOWN. Buying 197 more shares at 506.00
#   - [DABUR-EQ @ 2022-09-01] SELL SIGNAL TRIGGERED. Selling 374 shares at 565.05
#   - [DABUR-EQ @ 2023-03-03] BUY SIGNAL TRIGGERED. Buying 188 shares at 531.55
#   - [DABUR-EQ @ 2023-07-12] SELL SIGNAL TRIGGERED. Selling 188 shares at 583.95
#   - [DABUR-EQ @ 2023-11-16] BUY SIGNAL TRIGGERED. Buying 187 shares at 532.25
#   - [DABUR-EQ @ 2024-06-14] SELL SIGNAL TRIGGERED. Selling 187 shares at 610.95
#   - [DABUR-EQ @ 2024-11-26] BUY SIGNAL TRIGGERED. Buying 190 shares at 524.00
#   - [DABUR-EQ @ 2025-04-04] AVERAGING DOWN. Buying 214 more shares at 466.90
#
# [2] Analyzing stock: GILLETTE-EQ
#   - [GILLETTE-EQ @ 2020-10-20] BUY SIGNAL TRIGGERED. Buying 18 shares at 5285.00
#   - [GILLETTE-EQ @ 2020-11-19] SELL SIGNAL TRIGGERED. Selling 18 shares at 5935.00
#   - [GILLETTE-EQ @ 2021-05-26] BUY SIGNAL TRIGGERED. Buying 18 shares at 5500.00
#   - [GILLETTE-EQ @ 2021-07-13] SELL SIGNAL TRIGGERED. Selling 18 shares at 5762.05
#   - [GILLETTE-EQ @ 2021-12-07] BUY SIGNAL TRIGGERED. Buying 18 shares at 5466.90
#   - [GILLETTE-EQ @ 2022-02-22] AVERAGING DOWN. Buying 21 more shares at 4750.00
#   - [GILLETTE-EQ @ 2022-08-29] SELL SIGNAL TRIGGERED. Selling 39 shares at 5333.00
#   - [GILLETTE-EQ @ 2022-12-26] BUY SIGNAL TRIGGERED. Buying 20 shares at 4899.00
#   - [GILLETTE-EQ @ 2023-03-20] AVERAGING DOWN. Buying 23 more shares at 4270.00
#   - [GILLETTE-EQ @ 2023-07-26] SELL SIGNAL TRIGGERED. Selling 43 shares at 5549.00
#   - [GILLETTE-EQ @ 2025-03-26] BUY SIGNAL TRIGGERED. Buying 12 shares at 7978.00
#
# [2] Analyzing stock: MARICO-EQ
#   - [MARICO-EQ @ 2022-01-25] BUY SIGNAL TRIGGERED. Buying 212 shares at 470.00
#   - [MARICO-EQ @ 2022-09-06] SELL SIGNAL TRIGGERED. Selling 212 shares at 520.00
#   - [MARICO-EQ @ 2023-01-25] BUY SIGNAL TRIGGERED. Buying 199 shares at 502.45
#   - [MARICO-EQ @ 2023-06-09] SELL SIGNAL TRIGGERED. Selling 199 shares at 545.45
#   - [MARICO-EQ @ 2024-01-30] BUY SIGNAL TRIGGERED. Buying 192 shares at 519.95
#   - [MARICO-EQ @ 2024-06-03] SELL SIGNAL TRIGGERED. Selling 192 shares at 609.00
#   - [MARICO-EQ @ 2025-03-06] BUY SIGNAL TRIGGERED. Buying 167 shares at 596.75
#   - [MARICO-EQ @ 2025-05-09] SELL SIGNAL TRIGGERED. Selling 167 shares at 712.00
#
# [2] Analyzing stock: ITC-EQ
#   - [ITC-EQ @ 2020-10-08] BUY SIGNAL TRIGGERED. Buying 739 shares at 135.28
#   - [ITC-EQ @ 2020-12-14] SELL SIGNAL TRIGGERED. Selling 739 shares at 173.33
#   - [ITC-EQ @ 2024-02-28] BUY SIGNAL TRIGGERED. Buying 263 shares at 379.68
#   - [ITC-EQ @ 2024-07-02] SELL SIGNAL TRIGGERED. Selling 263 shares at 404.20
#   - [ITC-EQ @ 2025-02-12] BUY SIGNAL TRIGGERED. Buying 242 shares at 413.15
#
# [2] Analyzing stock: TITAN-EQ
#   - [TITAN-EQ @ 2022-06-08] BUY SIGNAL TRIGGERED. Buying 47 shares at 2106.05
#   - [TITAN-EQ @ 2022-07-01] AVERAGING DOWN. Buying 52 more shares at 1895.00
#   - [TITAN-EQ @ 2022-09-14] SELL SIGNAL TRIGGERED. Selling 99 shares at 2645.00
#   - [TITAN-EQ @ 2023-03-13] BUY SIGNAL TRIGGERED. Buying 42 shares at 2372.75
#   - [TITAN-EQ @ 2023-05-16] SELL SIGNAL TRIGGERED. Selling 42 shares at 2785.00
#   - [TITAN-EQ @ 2024-06-27] BUY SIGNAL TRIGGERED. Buying 29 shares at 3370.00
#   - [TITAN-EQ @ 2024-09-30] SELL SIGNAL TRIGGERED. Selling 29 shares at 3788.00
#   - [TITAN-EQ @ 2024-11-19] BUY SIGNAL TRIGGERED. Buying 31 shares at 3192.00
#
# [2] Analyzing stock: PAGEIND-EQ
#   - [PAGEIND-EQ @ 2023-01-10] BUY SIGNAL TRIGGERED. Buying 2 shares at 41469.80
#   - [PAGEIND-EQ @ 2023-03-08] AVERAGING DOWN. Buying 2 more shares at 37188.00
#   - [PAGEIND-EQ @ 2024-07-09] SELL SIGNAL TRIGGERED. Selling 4 shares at 39419.00
#   - [PAGEIND-EQ @ 2025-04-08] BUY SIGNAL TRIGGERED. Buying 2 shares at 41500.00
#   - [PAGEIND-EQ @ 2025-05-26] SELL SIGNAL TRIGGERED. Selling 2 shares at 47730.00
#
# [2] Analyzing stock: BATAINDIA-EQ
#   - [BATAINDIA-EQ @ 2022-05-18] BUY SIGNAL TRIGGERED. Buying 56 shares at 1765.00
#   - [BATAINDIA-EQ @ 2022-09-23] SELL SIGNAL TRIGGERED. Selling 56 shares at 1908.85
#   - [BATAINDIA-EQ @ 2022-10-27] BUY SIGNAL TRIGGERED. Buying 55 shares at 1805.15
#   - [BATAINDIA-EQ @ 2023-01-16] AVERAGING DOWN. Buying 63 more shares at 1580.40
#   - [BATAINDIA-EQ @ 2023-07-18] SELL SIGNAL TRIGGERED. Selling 118 shares at 1694.95
#   - [BATAINDIA-EQ @ 2024-01-23] BUY SIGNAL TRIGGERED. Buying 65 shares at 1517.90
#   - [BATAINDIA-EQ @ 2024-04-02] AVERAGING DOWN. Buying 74 more shares at 1350.05
#
# [2] Analyzing stock: HAVELLS-EQ
#   - [HAVELLS-EQ @ 2022-03-10] BUY SIGNAL TRIGGERED. Buying 89 shares at 1115.00
#   - [HAVELLS-EQ @ 2022-09-05] SELL SIGNAL TRIGGERED. Selling 89 shares at 1386.10
#   - [HAVELLS-EQ @ 2022-12-19] BUY SIGNAL TRIGGERED. Buying 86 shares at 1152.05
#   - [HAVELLS-EQ @ 2023-06-06] SELL SIGNAL TRIGGERED. Selling 86 shares at 1349.90
#   - [HAVELLS-EQ @ 2024-12-19] BUY SIGNAL TRIGGERED. Buying 59 shares at 1684.00
#   - [HAVELLS-EQ @ 2025-01-28] AVERAGING DOWN. Buying 66 more shares at 1507.20
#
# [2] Analyzing stock: WHIRLPOOL-EQ
#   - [WHIRLPOOL-EQ @ 2021-05-19] BUY SIGNAL TRIGGERED. Buying 47 shares at 2091.15
#   - [WHIRLPOOL-EQ @ 2021-11-10] SELL SIGNAL TRIGGERED. Selling 47 shares at 2292.70
#   - [WHIRLPOOL-EQ @ 2021-12-15] BUY SIGNAL TRIGGERED. Buying 53 shares at 1885.00
#   - [WHIRLPOOL-EQ @ 2022-02-22] AVERAGING DOWN. Buying 60 more shares at 1653.00
#   - [WHIRLPOOL-EQ @ 2022-09-08] SELL SIGNAL TRIGGERED. Selling 113 shares at 1819.50
#   - [WHIRLPOOL-EQ @ 2022-11-11] BUY SIGNAL TRIGGERED. Buying 65 shares at 1526.85
#   - [WHIRLPOOL-EQ @ 2023-02-02] AVERAGING DOWN. Buying 76 more shares at 1310.00
#   - [WHIRLPOOL-EQ @ 2023-08-01] SELL SIGNAL TRIGGERED. Selling 141 shares at 1466.00
#   - [WHIRLPOOL-EQ @ 2024-01-11] BUY SIGNAL TRIGGERED. Buying 73 shares at 1355.90
#   - [WHIRLPOOL-EQ @ 2024-02-27] AVERAGING DOWN. Buying 82 more shares at 1215.00
#   - [WHIRLPOOL-EQ @ 2024-06-12] SELL SIGNAL TRIGGERED. Selling 155 shares at 1761.00
#   - [WHIRLPOOL-EQ @ 2025-01-14] BUY SIGNAL TRIGGERED. Buying 62 shares at 1595.10
#   - [WHIRLPOOL-EQ @ 2025-01-30] AVERAGING DOWN. Buying 79 more shares at 1260.80
#
# [2] Analyzing stock: VOLTAS-EQ
#   - [VOLTAS-EQ @ 2022-05-25] BUY SIGNAL TRIGGERED. Buying 98 shares at 1019.80
#   - [VOLTAS-EQ @ 2022-09-20] AVERAGING DOWN. Buying 110 more shares at 904.00
#   - [VOLTAS-EQ @ 2023-09-21] SELL SIGNAL TRIGGERED. Selling 208 shares at 870.00
#   - [VOLTAS-EQ @ 2025-02-13] BUY SIGNAL TRIGGERED. Buying 76 shares at 1300.00
#
# [2] Analyzing stock: GLAXO-EQ
#   - [GLAXO-EQ @ 2021-03-15] BUY SIGNAL TRIGGERED. Buying 68 shares at 1465.00
#   - [GLAXO-EQ @ 2021-07-15] SELL SIGNAL TRIGGERED. Selling 68 shares at 1549.00
#   - [GLAXO-EQ @ 2022-05-13] BUY SIGNAL TRIGGERED. Buying 67 shares at 1485.00
#   - [GLAXO-EQ @ 2022-11-14] AVERAGING DOWN. Buying 75 more shares at 1331.95
#   - [GLAXO-EQ @ 2023-07-03] SELL SIGNAL TRIGGERED. Selling 142 shares at 1420.00
#   - [GLAXO-EQ @ 2024-12-30] BUY SIGNAL TRIGGERED. Buying 43 shares at 2274.45
#   - [GLAXO-EQ @ 2025-01-29] AVERAGING DOWN. Buying 49 more shares at 2028.20
#   - [GLAXO-EQ @ 2025-04-21] SELL SIGNAL TRIGGERED. Selling 92 shares at 2907.00
#
# [2] Analyzing stock: ABBOTINDIA-EQ
#   - [ABBOTINDIA-EQ @ 2020-11-20] BUY SIGNAL TRIGGERED. Buying 6 shares at 15298.70
#   - [ABBOTINDIA-EQ @ 2021-06-10] SELL SIGNAL TRIGGERED. Selling 6 shares at 16200.00
#   - [ABBOTINDIA-EQ @ 2022-02-02] BUY SIGNAL TRIGGERED. Buying 6 shares at 16234.00
#   - [ABBOTINDIA-EQ @ 2022-07-21] SELL SIGNAL TRIGGERED. Selling 6 shares at 20027.00
#
# [2] Analyzing stock: PFIZER-EQ
#   - [PFIZER-EQ @ 2021-03-18] BUY SIGNAL TRIGGERED. Buying 22 shares at 4500.00
#   - [PFIZER-EQ @ 2021-06-09] SELL SIGNAL TRIGGERED. Selling 22 shares at 5450.00
#   - [PFIZER-EQ @ 2021-12-03] BUY SIGNAL TRIGGERED. Buying 20 shares at 4953.30
#   - [PFIZER-EQ @ 2022-01-28] AVERAGING DOWN. Buying 22 more shares at 4421.00
#   - [PFIZER-EQ @ 2022-11-09] SELL SIGNAL TRIGGERED. Selling 42 shares at 4470.00
#   - [PFIZER-EQ @ 2023-02-10] BUY SIGNAL TRIGGERED. Buying 25 shares at 3898.70
#   - [PFIZER-EQ @ 2023-03-28] AVERAGING DOWN. Buying 28 more shares at 3475.00
#   - [PFIZER-EQ @ 2023-10-13] SELL SIGNAL TRIGGERED. Selling 53 shares at 3951.00
#   - [PFIZER-EQ @ 2025-01-24] BUY SIGNAL TRIGGERED. Buying 20 shares at 4811.10
#   - [PFIZER-EQ @ 2025-02-10] AVERAGING DOWN. Buying 23 more shares at 4301.00
#
# [2] Analyzing stock: SANOFI-EQ
#   - [SANOFI-EQ @ 2021-02-12] BUY SIGNAL TRIGGERED. Buying 12 shares at 7790.00
#   - [SANOFI-EQ @ 2021-08-16] SELL SIGNAL TRIGGERED. Selling 12 shares at 8600.00
#   - [SANOFI-EQ @ 2021-12-20] BUY SIGNAL TRIGGERED. Buying 13 shares at 7570.00
#   - [SANOFI-EQ @ 2022-05-10] AVERAGING DOWN. Buying 14 more shares at 6710.50
#   - [SANOFI-EQ @ 2023-05-18] SELL SIGNAL TRIGGERED. Selling 27 shares at 6564.00
#   - [SANOFI-EQ @ 2024-07-08] BUY SIGNAL TRIGGERED. Buying 15 shares at 6599.95
#   - [SANOFI-EQ @ 2025-01-13] AVERAGING DOWN. Buying 16 more shares at 5908.15
#
# [2] Analyzing stock: MARUTI-EQ
#   - [MARUTI-EQ @ 2021-04-27] BUY SIGNAL TRIGGERED. Buying 14 shares at 6669.95
#   - [MARUTI-EQ @ 2021-11-04] SELL SIGNAL TRIGGERED. Selling 14 shares at 7774.70
#   - [MARUTI-EQ @ 2023-03-20] BUY SIGNAL TRIGGERED. Buying 12 shares at 8316.85
#   - [MARUTI-EQ @ 2023-06-02] SELL SIGNAL TRIGGERED. Selling 12 shares at 9389.00
#   - [MARUTI-EQ @ 2024-11-14] BUY SIGNAL TRIGGERED. Buying 9 shares at 11055.00
#   - [MARUTI-EQ @ 2025-06-10] SELL SIGNAL TRIGGERED. Selling 9 shares at 12660.00
#
# [2] Analyzing stock: ASIANPAINT-EQ
#   - [ASIANPAINT-EQ @ 2022-04-18] BUY SIGNAL TRIGGERED. Buying 32 shares at 3056.00
#   - [ASIANPAINT-EQ @ 2022-06-09] AVERAGING DOWN. Buying 37 more shares at 2680.00
#   - [ASIANPAINT-EQ @ 2022-09-02] SELL SIGNAL TRIGGERED. Selling 69 shares at 3489.00
#   - [ASIANPAINT-EQ @ 2023-01-05] BUY SIGNAL TRIGGERED. Buying 32 shares at 3039.55
#   - [ASIANPAINT-EQ @ 2023-01-30] AVERAGING DOWN. Buying 36 more shares at 2724.00
#   - [ASIANPAINT-EQ @ 2023-06-21] SELL SIGNAL TRIGGERED. Selling 68 shares at 3318.70
#   - [ASIANPAINT-EQ @ 2024-02-12] BUY SIGNAL TRIGGERED. Buying 33 shares at 2951.65
#   - [ASIANPAINT-EQ @ 2024-09-03] SELL SIGNAL TRIGGERED. Selling 33 shares at 3164.95
#   - [ASIANPAINT-EQ @ 2024-11-29] BUY SIGNAL TRIGGERED. Buying 40 shares at 2458.05
#   - [ASIANPAINT-EQ @ 2025-02-28] AVERAGING DOWN. Buying 45 more shares at 2210.00
#
# [2] Analyzing stock: BERGEPAINT-EQ
#   - [BERGEPAINT-EQ @ 2021-12-07] BUY SIGNAL TRIGGERED. Buying 165 shares at 605.96
#   - [BERGEPAINT-EQ @ 2022-03-04] AVERAGING DOWN. Buying 184 more shares at 542.92
#   - [BERGEPAINT-EQ @ 2023-06-01] SELL SIGNAL TRIGGERED. Selling 349 shares at 543.75
#   - [BERGEPAINT-EQ @ 2024-03-13] BUY SIGNAL TRIGGERED. Buying 176 shares at 566.75
#   - [BERGEPAINT-EQ @ 2024-04-22] AVERAGING DOWN. Buying 196 more shares at 510.00
#   - [BERGEPAINT-EQ @ 2024-09-12] SELL SIGNAL TRIGGERED. Selling 372 shares at 621.00
#   - [BERGEPAINT-EQ @ 2024-12-05] BUY SIGNAL TRIGGERED. Buying 208 shares at 480.00
#   - [BERGEPAINT-EQ @ 2025-05-15] SELL SIGNAL TRIGGERED. Selling 208 shares at 562.00
#
# [2] Analyzing stock: BAJAJ-AUTO-EQ
#   - [BAJAJ-AUTO-EQ @ 2021-09-22] BUY SIGNAL TRIGGERED. Buying 26 shares at 3732.00
#   - [BAJAJ-AUTO-EQ @ 2021-11-29] AVERAGING DOWN. Buying 30 more shares at 3321.00
#   - [BAJAJ-AUTO-EQ @ 2022-05-17] SELL SIGNAL TRIGGERED. Selling 56 shares at 3725.10
#   - [BAJAJ-AUTO-EQ @ 2022-12-14] BUY SIGNAL TRIGGERED. Buying 27 shares at 3650.00
#   - [BAJAJ-AUTO-EQ @ 2023-03-22] SELL SIGNAL TRIGGERED. Selling 27 shares at 3921.75
#   - [BAJAJ-AUTO-EQ @ 2024-12-24] BUY SIGNAL TRIGGERED. Buying 11 shares at 8745.00
#   - [BAJAJ-AUTO-EQ @ 2025-03-04] AVERAGING DOWN. Buying 13 more shares at 7652.10
#
# ==================================================================================
# --- BACKTESTING COMPLETE: FINAL SUMMARY ---
# ==================================================================================
#
# ============================ COMPLETED TRADES SUMMARY ============================
#              Stock                Entry Date                 Exit Date  Avg Entry Price  Exit Price  Investment  Sale Value    Profit   Profit %  Times Averaged
# 0            LT-EQ 2020-10-08 00:00:00+05:30 2020-11-27 00:00:00+05:30       890.300000     1129.00    99713.60   126448.00  26734.40  26.811187               0
# 1            LT-EQ 2022-04-27 00:00:00+05:30 2022-09-08 00:00:00+05:30      1576.626984     1967.90   198655.00   247955.40  49300.40  24.817095               1
# 2      RELIANCE-EQ 2021-04-13 00:00:00+05:30 2021-08-27 00:00:00+05:30       873.360000     1015.44    99563.04   115760.16  16197.12  16.268206               0
# 3      RELIANCE-EQ 2023-02-03 00:00:00+05:30 2023-06-30 00:00:00+05:30      1066.280000     1155.89    99164.04   107497.77   8333.73   8.403984               0
# 4      RELIANCE-EQ 2024-10-22 00:00:00+05:30 2025-06-05 00:00:00+05:30      1295.668831     1428.00   199533.00   219912.00  20379.00  10.213348               1
# 5      HDFCBANK-EQ 2022-02-15 00:00:00+05:30 2022-09-15 00:00:00+05:30      1392.813380     1530.00   197779.50   217260.00  19480.50   9.849605               1
# 6      HDFCBANK-EQ 2023-09-21 00:00:00+05:30 2024-06-26 00:00:00+05:30      1461.544118     1707.95   198770.00   232281.20  33511.20  16.859285               1
# 7     ICICIBANK-EQ 2022-05-23 00:00:00+05:30 2022-08-11 00:00:00+05:30       709.550000      860.05    99337.00   120407.00  21070.00  21.210626               0
# 8     ICICIBANK-EQ 2023-03-28 00:00:00+05:30 2023-05-16 00:00:00+05:30       855.550000      950.00    99243.80   110200.00  10956.20  11.039682               0
# 9      AXISBANK-EQ 2021-12-21 00:00:00+05:30 2022-04-18 00:00:00+05:30       683.000000      780.00    99718.00   113880.00  14162.00  14.202050               0
# 10     AXISBANK-EQ 2022-05-16 00:00:00+05:30 2022-09-09 00:00:00+05:30       639.850000      787.95    99816.60   122920.20  23103.60  23.146050               0
# 11     AXISBANK-EQ 2024-12-13 00:00:00+05:30 2025-05-22 00:00:00+05:30      1080.691304     1196.70   198847.20   220192.80  21345.60  10.734675               1
# 12    KOTAKBANK-EQ 2021-07-13 00:00:00+05:30 2021-10-13 00:00:00+05:30      1743.000000     2004.00    99351.00   114228.00  14877.00  14.974182               0
# 13    KOTAKBANK-EQ 2022-02-22 00:00:00+05:30 2022-09-13 00:00:00+05:30      1790.000000     1933.00    98450.00   106315.00   7865.00   7.988827               0
# 14    KOTAKBANK-EQ 2023-02-07 00:00:00+05:30 2023-05-29 00:00:00+05:30      1752.200000     1956.50    99875.40   111520.50  11645.10  11.659628               0
# 15    KOTAKBANK-EQ 2023-09-22 00:00:00+05:30 2024-09-17 00:00:00+05:30      1758.000000     1839.40    98448.00   103006.40   4558.40   4.630262               0
# 16      HCLTECH-EQ 2022-04-20 00:00:00+05:30 2022-12-07 00:00:00+05:30      1010.277157     1114.00   199024.60   219458.00  20433.40  10.266771               1
# 17         INFY-EQ 2022-05-12 00:00:00+05:30 2023-02-10 00:00:00+05:30      1433.122302     1612.95   199204.00   224200.05  24996.05  12.547966               1
# 18         INFY-EQ 2023-04-03 00:00:00+05:30 2023-09-25 00:00:00+05:30      1336.410135     1489.85   197788.70   220497.80  22709.10  11.481495               1
# 19         INFY-EQ 2024-05-31 00:00:00+05:30 2024-07-19 00:00:00+05:30      1409.800000     1844.00    98686.00   129080.00  30394.00  30.798695               0
# 20          TCS-EQ 2022-05-06 00:00:00+05:30 2023-01-27 00:00:00+05:30      3263.266667     3426.00   195796.00   205560.00   9764.00   4.986823               1
# 21          TCS-EQ 2023-05-18 00:00:00+05:30 2023-07-18 00:00:00+05:30      3225.950000     3476.00    96778.50   104280.00   7501.50   7.751205               0
# 22      HDFCAMC-EQ 2020-10-27 00:00:00+05:30 2020-12-21 00:00:00+05:30      2290.000000     2861.90    98470.00   123061.70  24591.70  24.973799               0
# 23      HDFCAMC-EQ 2021-11-17 00:00:00+05:30 2022-12-01 00:00:00+05:30      2483.491772     2190.30   196195.85   173033.70 -23162.15 -11.805627               1
# 24      HDFCAMC-EQ 2023-03-06 00:00:00+05:30 2023-07-13 00:00:00+05:30      1800.000000     2349.95    99000.00   129247.25  30247.25  30.552778               0
# 25      HDFCAMC-EQ 2025-02-04 00:00:00+05:30 2025-05-26 00:00:00+05:30      3844.950000     4810.00    99968.70   125060.00  25091.30  25.099156               0
# 26    NAM-INDIA-EQ 2020-10-08 00:00:00+05:30 2020-12-11 00:00:00+05:30       270.350000      308.95    99759.15   114002.55  14243.40  14.277788               0
# 27    NAM-INDIA-EQ 2022-01-25 00:00:00+05:30 2023-07-10 00:00:00+05:30       308.490881      286.50   199593.60   185365.50 -14228.10  -7.128535               1
# 28    NAM-INDIA-EQ 2025-02-20 00:00:00+05:30 2025-06-10 00:00:00+05:30       523.350000      809.00    99959.85   154519.00  54559.15  54.581064               0
# 29     HDFCLIFE-EQ 2021-12-21 00:00:00+05:30 2023-01-04 00:00:00+05:30       599.603604      599.00   199668.00   199467.00   -201.00  -0.100667               1
# 30     HDFCLIFE-EQ 2023-02-28 00:00:00+05:30 2023-06-12 00:00:00+05:30       490.900000      585.95    99652.70   118947.85  19295.15  19.362396               0
# 31     HDFCLIFE-EQ 2024-02-16 00:00:00+05:30 2024-08-08 00:00:00+05:30       588.500000      691.10    99456.50   116795.90  17339.40  17.434155               0
# 32     HDFCLIFE-EQ 2025-01-15 00:00:00+05:30 2025-05-14 00:00:00+05:30       604.500000      740.00    99742.50   122100.00  22357.50  22.415219               0
# 33   ICICIPRULI-EQ 2022-01-20 00:00:00+05:30 2022-09-02 00:00:00+05:30       542.802174      593.50   199751.20   218408.00  18656.80   9.340019               1
# 34   ICICIPRULI-EQ 2022-11-23 00:00:00+05:30 2023-06-28 00:00:00+05:30       427.915451      582.40   199408.60   271398.40  71989.80  36.101653               1
# 35   ICICIPRULI-EQ 2024-02-05 00:00:00+05:30 2024-04-10 00:00:00+05:30       507.000000      627.90    99879.00   123696.30  23817.30  23.846154               0
# 36      ICICIGI-EQ 2021-12-16 00:00:00+05:30 2023-06-30 00:00:00+05:30      1322.231788     1332.00   199657.00   201132.00   1475.00   0.738767               1
# 37   BAJAJFINSV-EQ 2020-10-08 00:00:00+05:30 2020-11-24 00:00:00+05:30       595.000000      881.99    99960.00   148174.32  48214.32  48.233613               0
# 38   BAJAJFINSV-EQ 2022-05-04 00:00:00+05:30 2022-09-20 00:00:00+05:30      1405.931489     1785.00   198236.34   251685.00  53448.66  26.962090               1
# 39   BAJAJFINSV-EQ 2023-02-23 00:00:00+05:30 2023-07-17 00:00:00+05:30      1362.000000     1620.00    99426.00   118260.00  18834.00  18.942731               0
# 40   BAJAJFINSV-EQ 2024-08-20 00:00:00+05:30 2024-09-05 00:00:00+05:30      1554.950000     1868.00    99516.80   119552.00  20035.20  20.132480               0
# 41   BAJAJFINSV-EQ 2025-01-01 00:00:00+05:30 2025-02-10 00:00:00+05:30      1565.000000     1804.90    98595.00   113708.70  15113.70  15.329073               0
# 42   BAJAJHLDNG-EQ 2020-10-08 00:00:00+05:30 2020-12-02 00:00:00+05:30      2431.050000     3094.30    99673.05   126866.30  27193.25  27.282450               0
# 43   BAJAJHLDNG-EQ 2022-06-24 00:00:00+05:30 2022-09-12 00:00:00+05:30      4525.000000     6660.65    99550.00   146534.30  46984.30  47.196685               0
# 44   BAJFINANCE-EQ 2022-05-11 00:00:00+05:30 2022-09-14 00:00:00+05:30      5634.058824     7272.15   191558.00   247253.10  55695.10  29.074797               1
# 45   BAJFINANCE-EQ 2023-01-12 00:00:00+05:30 2023-06-21 00:00:00+05:30      5906.550000     7275.00    94504.80   116400.00  21895.20  23.168347               0
# 46   BAJFINANCE-EQ 2024-02-13 00:00:00+05:30 2024-09-26 00:00:00+05:30      6600.000000     7640.00    99000.00   114600.00  15600.00  15.757576               0
# 47   BAJFINANCE-EQ 2024-12-23 00:00:00+05:30 2025-01-29 00:00:00+05:30      6897.000000     7657.25    96558.00   107201.50  10643.50  11.022909               0
# 48   HINDUNILVR-EQ 2021-12-17 00:00:00+05:30 2022-07-19 00:00:00+05:30      2129.075269     2549.95   198004.00   237145.35  39141.35  19.767959               1
# 49   HINDUNILVR-EQ 2023-09-13 00:00:00+05:30 2024-07-16 00:00:00+05:30      2357.809524     2625.95   198056.00   220579.80  22523.80  11.372440               1
# 50    NESTLEIND-EQ 2020-10-14 00:00:00+05:30 2020-12-02 00:00:00+05:30      1567.400000     1741.82    98746.20   109734.66  10988.46  11.127983               0
# 51    NESTLEIND-EQ 2021-05-14 00:00:00+05:30 2021-05-31 00:00:00+05:30      1671.700000     1750.90    98630.30   103303.10   4672.80   4.737692               0
# 52    NESTLEIND-EQ 2022-03-07 00:00:00+05:30 2022-08-22 00:00:00+05:30      1710.000000     1940.10    99180.00   112525.80  13345.80  13.456140               0
# 53    NESTLEIND-EQ 2024-10-31 00:00:00+05:30 2025-06-02 00:00:00+05:30      2287.000000     2400.00    98341.00   103200.00   4859.00   4.940971               0
# 54         PGHH-EQ 2020-10-08 00:00:00+05:30 2020-12-04 00:00:00+05:30      9932.000000    10997.00    99320.00   109970.00  10650.00  10.722916               0
# 55         PGHH-EQ 2022-05-18 00:00:00+05:30 2023-01-03 00:00:00+05:30     13284.000000    14278.00    92988.00    99946.00   6958.00   7.482686               0
# 56         PGHH-EQ 2023-02-14 00:00:00+05:30 2023-07-12 00:00:00+05:30     13746.500000    14712.45    96225.50   102987.15   6761.65   7.026880               0
# 57         PGHH-EQ 2024-04-03 00:00:00+05:30 2024-08-13 00:00:00+05:30     16199.000000    17200.00    97194.00   103200.00   6006.00   6.179394               0
# 58   PIDILITIND-EQ 2022-05-10 00:00:00+05:30 2022-08-30 00:00:00+05:30      2217.050000     2715.50    99767.25   122197.50  22430.25  22.482578               0
# 59   PIDILITIND-EQ 2023-02-16 00:00:00+05:30 2023-06-26 00:00:00+05:30      2319.000000     2650.00    99717.00   113950.00  14233.00  14.273394               0
# 60   PIDILITIND-EQ 2023-10-26 00:00:00+05:30 2024-01-03 00:00:00+05:30      2321.000000     2749.00    99803.00   118207.00  18404.00  18.440327               0
# 61       COLPAL-EQ 2021-11-22 00:00:00+05:30 2022-05-19 00:00:00+05:30      1476.900000     1589.00    98952.30   106463.00   7510.70   7.590223               0
# 62       COLPAL-EQ 2023-01-13 00:00:00+05:30 2023-06-02 00:00:00+05:30      1493.850000     1612.00    98594.10   106392.00   7797.90   7.909094               0
# 63        DABUR-EQ 2022-01-19 00:00:00+05:30 2022-09-01 00:00:00+05:30       533.401872      565.05   199492.30   211328.70  11836.40   5.933262               1
# 64        DABUR-EQ 2023-03-03 00:00:00+05:30 2023-07-12 00:00:00+05:30       531.550000      583.95    99931.40   109782.60   9851.20   9.857963               0
# 65        DABUR-EQ 2023-11-16 00:00:00+05:30 2024-06-14 00:00:00+05:30       532.250000      610.95    99530.75   114247.65  14716.90  14.786285               0
# 66     GILLETTE-EQ 2020-10-20 00:00:00+05:30 2020-11-19 00:00:00+05:30      5285.000000     5935.00    95130.00   106830.00  11700.00  12.298959               0
# 67     GILLETTE-EQ 2021-05-26 00:00:00+05:30 2021-07-13 00:00:00+05:30      5500.000000     5762.05    99000.00   103716.90   4716.90   4.764545               0
# 68     GILLETTE-EQ 2021-12-07 00:00:00+05:30 2022-08-29 00:00:00+05:30      5080.876923     5333.00   198154.20   207987.00   9832.80   4.962196               1
# 69     GILLETTE-EQ 2022-12-26 00:00:00+05:30 2023-07-26 00:00:00+05:30      4562.558140     5549.00   196190.00   238607.00  42417.00  21.620368               1
# 70       MARICO-EQ 2022-01-25 00:00:00+05:30 2022-09-06 00:00:00+05:30       470.000000      520.00    99640.00   110240.00  10600.00  10.638298               0
# 71       MARICO-EQ 2023-01-25 00:00:00+05:30 2023-06-09 00:00:00+05:30       502.450000      545.45    99987.55   108544.55   8557.00   8.558065               0
# 72       MARICO-EQ 2024-01-30 00:00:00+05:30 2024-06-03 00:00:00+05:30       519.950000      609.00    99830.40   116928.00  17097.60  17.126647               0
# 73       MARICO-EQ 2025-03-06 00:00:00+05:30 2025-05-09 00:00:00+05:30       596.750000      712.00    99657.25   118904.00  19246.75  19.312945               0
# 74          ITC-EQ 2020-10-08 00:00:00+05:30 2020-12-14 00:00:00+05:30       135.280000      173.33    99971.92   128090.87  28118.95  28.126848               0
# 75          ITC-EQ 2024-02-28 00:00:00+05:30 2024-07-02 00:00:00+05:30       379.680000      404.20    99855.84   106304.60   6448.76   6.458070               0
# 76        TITAN-EQ 2022-06-08 00:00:00+05:30 2022-09-14 00:00:00+05:30      1995.195455     2645.00   197524.35   261855.00  64330.65  32.568466               1
# 77        TITAN-EQ 2023-03-13 00:00:00+05:30 2023-05-16 00:00:00+05:30      2372.750000     2785.00    99655.50   116970.00  17314.50  17.374355               0
# 78        TITAN-EQ 2024-06-27 00:00:00+05:30 2024-09-30 00:00:00+05:30      3370.000000     3788.00    97730.00   109852.00  12122.00  12.403561               0
# 79      PAGEIND-EQ 2023-01-10 00:00:00+05:30 2024-07-09 00:00:00+05:30     39328.900000    39419.00   157315.60   157676.00    360.40   0.229094               1
# 80      PAGEIND-EQ 2025-04-08 00:00:00+05:30 2025-05-26 00:00:00+05:30     41500.000000    47730.00    83000.00    95460.00  12460.00  15.012048               0
# 81    BATAINDIA-EQ 2022-05-18 00:00:00+05:30 2022-09-23 00:00:00+05:30      1765.000000     1908.85    98840.00   106895.60   8055.60   8.150142               0
# 82    BATAINDIA-EQ 2022-10-27 00:00:00+05:30 2023-07-18 00:00:00+05:30      1685.156356     1694.95   198848.45   200004.10   1155.65   0.581171               1
# 83      HAVELLS-EQ 2022-03-10 00:00:00+05:30 2022-09-05 00:00:00+05:30      1115.000000     1386.10    99235.00   123362.90  24127.90  24.313901               0
# 84      HAVELLS-EQ 2022-12-19 00:00:00+05:30 2023-06-06 00:00:00+05:30      1152.050000     1349.90    99076.30   116091.40  17015.10  17.173734               0
# 85    WHIRLPOOL-EQ 2021-05-19 00:00:00+05:30 2021-11-10 00:00:00+05:30      2091.150000     2292.70    98284.05   107756.90   9472.85   9.638237               0
# 86    WHIRLPOOL-EQ 2021-12-15 00:00:00+05:30 2022-09-08 00:00:00+05:30      1761.814159     1819.50   199085.00   205603.50   6518.50   3.274230               1
# 87    WHIRLPOOL-EQ 2022-11-11 00:00:00+05:30 2023-08-01 00:00:00+05:30      1409.966312     1466.00   198805.25   206706.00   7900.75   3.974115               1
# 88    WHIRLPOOL-EQ 2024-01-11 00:00:00+05:30 2024-06-12 00:00:00+05:30      1281.359355     1761.00   198610.70   272955.00  74344.30  37.432173               1
# 89       VOLTAS-EQ 2022-05-25 00:00:00+05:30 2023-09-21 00:00:00+05:30       958.559615      870.00   199380.40   180960.00 -18420.40  -9.238822               1
# 90        GLAXO-EQ 2021-03-15 00:00:00+05:30 2021-07-15 00:00:00+05:30      1465.000000     1549.00    99620.00   105332.00   5712.00   5.733788               0
# 91        GLAXO-EQ 2022-05-13 00:00:00+05:30 2023-07-03 00:00:00+05:30      1404.163732     1420.00   199391.25   201640.00   2248.75   1.127808               1
# 92        GLAXO-EQ 2024-12-30 00:00:00+05:30 2025-04-21 00:00:00+05:30      2143.295109     2907.00   197183.15   267444.00  70260.85  35.632279               1
# 93   ABBOTINDIA-EQ 2020-11-20 00:00:00+05:30 2021-06-10 00:00:00+05:30     15298.700000    16200.00    91792.20    97200.00   5407.80   5.891350               0
# 94   ABBOTINDIA-EQ 2022-02-02 00:00:00+05:30 2022-07-21 00:00:00+05:30     16234.000000    20027.00    97404.00   120162.00  22758.00  23.364544               0
# 95       PFIZER-EQ 2021-03-18 00:00:00+05:30 2021-06-09 00:00:00+05:30      4500.000000     5450.00    99000.00   119900.00  20900.00  21.111111               0
# 96       PFIZER-EQ 2021-12-03 00:00:00+05:30 2022-11-09 00:00:00+05:30      4674.476190     4470.00   196328.00   187740.00  -8588.00  -4.374312               1
# 97       PFIZER-EQ 2023-02-10 00:00:00+05:30 2023-10-13 00:00:00+05:30      3674.858491     3951.00   194767.50   209403.00  14635.50   7.514344               1
# 98       SANOFI-EQ 2021-02-12 00:00:00+05:30 2021-08-16 00:00:00+05:30      7790.000000     8600.00    93480.00   103200.00   9720.00  10.397946               0
# 99       SANOFI-EQ 2021-12-20 00:00:00+05:30 2023-05-18 00:00:00+05:30      7124.333333     6564.00   192357.00   177228.00 -15129.00  -7.865063               1
# 100      MARUTI-EQ 2021-04-27 00:00:00+05:30 2021-11-04 00:00:00+05:30      6669.950000     7774.70    93379.30   108845.80  15466.50  16.563093               0
# 101      MARUTI-EQ 2023-03-20 00:00:00+05:30 2023-06-02 00:00:00+05:30      8316.850000     9389.00    99802.20   112668.00  12865.80  12.891299               0
# 102      MARUTI-EQ 2024-11-14 00:00:00+05:30 2025-06-10 00:00:00+05:30     11055.000000    12660.00    99495.00   113940.00  14445.00  14.518318               0
# 103  ASIANPAINT-EQ 2022-04-18 00:00:00+05:30 2022-09-02 00:00:00+05:30      2854.376812     3489.00   196952.00   240741.00  43789.00  22.233336               1
# 104  ASIANPAINT-EQ 2023-01-05 00:00:00+05:30 2023-06-21 00:00:00+05:30      2872.494118     3318.70   195329.60   225671.60  30342.00  15.533744               1
# 105  ASIANPAINT-EQ 2024-02-12 00:00:00+05:30 2024-09-03 00:00:00+05:30      2951.650000     3164.95    97404.45   104443.35   7038.90   7.226467               0
# 106  BERGEPAINT-EQ 2021-12-07 00:00:00+05:30 2023-06-01 00:00:00+05:30       572.724011      543.75   199880.68   189768.75 -10111.93  -5.058983               1
# 107  BERGEPAINT-EQ 2024-03-13 00:00:00+05:30 2024-09-12 00:00:00+05:30       536.849462      621.00   199708.00   231012.00  31304.00  15.674885               1
# 108  BERGEPAINT-EQ 2024-12-05 00:00:00+05:30 2025-05-15 00:00:00+05:30       480.000000      562.00    99840.00   116896.00  17056.00  17.083333               0
# 109  BAJAJ-AUTO-EQ 2021-09-22 00:00:00+05:30 2022-05-17 00:00:00+05:30      3511.821429     3725.10   196662.00   208605.60  11943.60   6.073161               1
# 110  BAJAJ-AUTO-EQ 2022-12-14 00:00:00+05:30 2023-03-22 00:00:00+05:30      3650.000000     3921.75    98550.00   105887.25   7337.25   7.445205               0
#
# Saved completed trades summary to '/content/drive/My Drive/stock_data/ma_strategy_completed.csv'
#
# ======================== OPEN TRADES (TARGET NOT MET) SUMMARY =======================
#             Stock Status                Entry Date  Avg Entry Price  Investment           Last Known Date  Last Price  Unrealized P/L  Unrealized P/L %  Shares
# 0           LT-EQ   Open 2025-02-13 00:00:00+05:30      3289.650000    98689.50 2025-06-17 00:00:00+05:30     3622.30         9979.50         10.112018      30
# 1      HCLTECH-EQ   Open 2025-03-19 00:00:00+05:30      1444.014493   199274.00 2025-06-17 00:00:00+05:30     1729.60        39410.80         19.777191     138
# 2         INFY-EQ   Open 2025-03-20 00:00:00+05:30      1462.222222   197400.00 2025-06-17 00:00:00+05:30     1639.90        23986.50         12.151216     135
# 3          TCS-EQ   Open 2025-02-18 00:00:00+05:30      3680.000000   195040.00 2025-06-17 00:00:00+05:30     3515.30        -8729.10         -4.475543      53
# 4   ICICIPRULI-EQ   Open 2025-01-22 00:00:00+05:30       584.064620   199750.10 2025-06-17 00:00:00+05:30      640.30        19232.50          9.628281     342
# 5      ICICIGI-EQ   Open 2025-01-14 00:00:00+05:30      1732.542105   197509.80 2025-06-17 00:00:00+05:30     1917.10        21039.60         10.652433     114
# 6   HINDUNILVR-EQ   Open 2024-12-19 00:00:00+05:30      2347.000000    98574.00 2025-06-17 00:00:00+05:30     2328.60         -772.80         -0.783980      42
# 7         PGHH-EQ   Open 2024-11-06 00:00:00+05:30     15230.000000   182760.00 2025-06-17 00:00:00+05:30    13380.00       -22200.00        -12.147078      12
# 8   PIDILITIND-EQ   Open 2025-01-01 00:00:00+05:30      2904.250000    98744.50 2025-06-17 00:00:00+05:30     3018.30         3877.70          3.927004      34
# 9       COLPAL-EQ   Open 2024-12-19 00:00:00+05:30      2606.355263   198083.00 2025-06-17 00:00:00+05:30     2382.00       -17051.00         -8.608008      76
# 10       DABUR-EQ   Open 2024-11-26 00:00:00+05:30       493.753960   199476.60 2025-06-17 00:00:00+05:30      472.05        -8768.40         -4.395704     404
# 11    GILLETTE-EQ   Open 2025-03-26 00:00:00+05:30      7978.000000    95736.00 2025-06-17 00:00:00+05:30    10380.00        28824.00         30.107796      12
# 12         ITC-EQ   Open 2025-02-12 00:00:00+05:30       413.150000    99982.30 2025-06-17 00:00:00+05:30      417.40         1028.50          1.028682     242
# 13       TITAN-EQ   Open 2024-11-19 00:00:00+05:30      3192.000000    98952.00 2025-06-17 00:00:00+05:30     3405.70         6624.70          6.694862      31
# 14   BATAINDIA-EQ   Open 2024-01-23 00:00:00+05:30      1428.541007   198567.20 2025-06-17 00:00:00+05:30     1218.00       -29265.20        -14.738184     139
# 15     HAVELLS-EQ   Open 2024-12-19 00:00:00+05:30      1590.649600   198831.20 2025-06-17 00:00:00+05:30     1535.00        -6956.20         -3.498545     125
# 16   WHIRLPOOL-EQ   Open 2025-01-14 00:00:00+05:30      1407.797163   198499.40 2025-06-17 00:00:00+05:30     1330.90       -10842.50         -5.462233     141
# 17      VOLTAS-EQ   Open 2025-02-13 00:00:00+05:30      1300.000000    98800.00 2025-06-17 00:00:00+05:30     1294.20         -440.80         -0.446154      76
# 18      PFIZER-EQ   Open 2025-01-24 00:00:00+05:30      4538.255814   195145.00 2025-06-17 00:00:00+05:30     5860.50        56856.50         29.135515      43
# 19      SANOFI-EQ   Open 2024-07-08 00:00:00+05:30      6242.891935   193529.65 2025-06-17 00:00:00+05:30     6051.00        -5948.65         -3.073767      31
# 20  ASIANPAINT-EQ   Open 2024-11-29 00:00:00+05:30      2326.729412   197772.00 2025-06-17 00:00:00+05:30     2264.80        -5264.00         -2.661651      85
# 21  BAJAJ-AUTO-EQ   Open 2024-12-24 00:00:00+05:30      8153.012500   195672.30 2025-06-17 00:00:00+05:30     8494.50         8195.70          4.188482      24
#
# Saved open trades summary to '/content/drive/My Drive/stock_data/ma_strategy_open.csv'
